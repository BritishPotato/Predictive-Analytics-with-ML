# %%
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import roc_auc_score

import pandas as pd

# %%
baby = pd.read_csv("C:/Users/HP/Desktop/baby.csv", engine="python")
cat = baby.iloc[:2].copy()
cat.set_value(0, "current_is_sale", 32424)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#    ï»¿  current_total_landing_count  current_other_landing_count  \
# 0    1                            1                            1
# 1    2                            1                            0
#
#    current_product_landing_count  current_cart_landing_count  \
# 0                              0                           0
# 1                              1                           0
#
#    current_sale_amount  current_is_sale  current_avg_cart_amount  \
# 0                    0            32424                        0
# 1                    0                0                        0
#
#    current_avg_visited_product_price referrer  last_1_day_session_count  \
# 0                                  0   google                         0
# 1                                  0   google                         0
#
#    last_7_day_session_count              date
# 0                         0  08/05/2014 09:09
# 1                         3  09/05/2014 18:33

# %%
## Import up sound alert dependencies
from IPython.display import Audio, display

def allDone():
  display(Audio(url='https://sound.peal.io/ps/audios/000/000/537/original/woo_vu_luvub_dub_dub.wav', autoplay=True))
## Insert whatever audio file you want above

allDone()
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="https://sound.peal.io/ps/audios/000/000/537/original/woo_vu_luvub_dub_dub.wav" type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
baby.columns[0]
# Out:
# 'ï»¿'

# %%
baby
# Out:
#    ï»¿  current_total_landing_count  current_other_landing_count  \
# 0    1                            1                            1
# 1    2                            1                            0
# 2    3                            1                            1
# 3    4                            2                            2
# 4    5                            1                            0
# 5    6                            1                            0
# 6    7                            4                            2
# 7    8                            2                            2
# 8    9                            3                            3
#
#    current_product_landing_count  current_cart_landing_count  \
# 0                              0                           0
# 1                              1                           0
# 2                              0                           0
# 3                              0                           0
# 4                              1                           0
# 5                              1                           0
# 6                              2                           0
# 7                              0                           0
# 8                              0                           0
#
#    current_sale_amount  current_is_sale  current_avg_cart_amount  \
# 0                    0                0                        0
# 1                    0                0                        0
# 2                    0                0                        0
# 3                    0                0                        0
# 4                    0                0                       69
# 5                    0                0                        0
# 6                    0                0                      180
# 7                    0                0                        0
# 8                    0                0                        0
#
#    current_avg_visited_product_price  referrer  last_1_day_session_count  \
# 0                                  0    google                         0
# 1                                  0    google                         0
# 2                                  0    google                         0
# 3                                  0  facebook                         1
# 4                                  0     other                        13
# 5                                  0     other                        33
# 6                                  0     other                         0
# 7                                  0     other                         2
# 8                                  0     other                         0
#
#    last_7_day_session_count              date
# 0                         0  08/05/2014 09:09
# 1                         3  09/05/2014 18:33
# 2                         1  17/05/2014 17:59
# 3                         7  18/05/2014 15:33
# 4                        13  15/05/2014 16:59
# 5                        33  17/05/2014 10:20
# 6                        36  16/05/2014 08:16
# 7                         2  08/05/2014 09:11
# 8                         1  07/05/2014 12:48

# %%
import pickle


f = open('store.pckl', 'wb')
pickle.dump(baby, f)
f.close()

f = open('store.pckl', 'rb')
obj = pickle.load(f)
f.close()

# %%
obj
# Out:
#    ï»¿  current_total_landing_count  current_other_landing_count  \
# 0    1                            1                            1
# 1    2                            1                            0
# 2    3                            1                            1
# 3    4                            2                            2
# 4    5                            1                            0
# 5    6                            1                            0
# 6    7                            4                            2
# 7    8                            2                            2
# 8    9                            3                            3
#
#    current_product_landing_count  current_cart_landing_count  \
# 0                              0                           0
# 1                              1                           0
# 2                              0                           0
# 3                              0                           0
# 4                              1                           0
# 5                              1                           0
# 6                              2                           0
# 7                              0                           0
# 8                              0                           0
#
#    current_sale_amount  current_is_sale  current_avg_cart_amount  \
# 0                    0                0                        0
# 1                    0                0                        0
# 2                    0                0                        0
# 3                    0                0                        0
# 4                    0                0                       69
# 5                    0                0                        0
# 6                    0                0                      180
# 7                    0                0                        0
# 8                    0                0                        0
#
#    current_avg_visited_product_price  referrer  last_1_day_session_count  \
# 0                                  0    google                         0
# 1                                  0    google                         0
# 2                                  0    google                         0
# 3                                  0  facebook                         1
# 4                                  0     other                        13
# 5                                  0     other                        33
# 6                                  0     other                         0
# 7                                  0     other                         2
# 8                                  0     other                         0
#
#    last_7_day_session_count              date
# 0                         0  08/05/2014 09:09
# 1                         3  09/05/2014 18:33
# 2                         1  17/05/2014 17:59
# 3                         7  18/05/2014 15:33
# 4                        13  15/05/2014 16:59
# 5                        33  17/05/2014 10:20
# 6                        36  16/05/2014 08:16
# 7                         2  08/05/2014 09:11
# 8                         1  07/05/2014 12:48
